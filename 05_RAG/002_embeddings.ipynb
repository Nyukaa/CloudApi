# %%
# Install VoyageAI lib
# %pip install voyageai
# Out:
# Requirement already satisfied: voyageai in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (0.5.0)
# Requirement already satisfied: aiohttp in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from voyageai) (3.14.3)
# Requirement already satisfied: aiolimiter in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from voyageai) (1.2.1)
# Requirement already satisfied: langchain-text-splitters>=0.3.8 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from voyageai) (1.1.2)
# Requirement already satisfied: numpy in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from voyageai) (2.4.6)
# Requirement already satisfied: pillow in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from voyageai) (12.3.0)
# Requirement already satisfied: pydantic>=2.7.4 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from voyageai) (2.13.4)
# Requirement already satisfied: requests in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from voyageai) (2.34.2)
# Requirement already satisfied: tenacity in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from voyageai) (9.1.4)
# Requirement already satisfied: tokenizers>=0.14.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from voyageai) (0.23.1)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.31 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from langchain-text-splitters>=0.3.8->voyageai) (1.6.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pydantic>=2.7.4->voyageai) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pydantic>=2.7.4->voyageai) (2.46.4)
# Requirement already satisfied: typing-extensions>=4.14.1 in /Users/annashitikova/Library/Python/3.11/lib/python/site-packages (from pydantic>=2.7.4->voyageai) (4.16.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pydantic>=2.7.4->voyageai) (0.4.4)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from tokenizers>=0.14.0->voyageai) (1.28.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from aiohttp->voyageai) (2.7.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from aiohttp->voyageai) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from aiohttp->voyageai) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from aiohttp->voyageai) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from aiohttp->voyageai) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from aiohttp->voyageai) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from aiohttp->voyageai) (1.24.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests->voyageai) (3.5.1)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests->voyageai) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests->voyageai) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests->voyageai) (2026.7.22)
# Requirement already satisfied: click<9.0.0,>=8.4.2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.14.0->voyageai) (8.5.0)
# Requirement already satisfied: filelock>=3.10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.14.0->voyageai) (3.32.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.14.0->voyageai) (2026.7.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.14.0->voyageai) (1.6.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.14.0->voyageai) (0.28.1)
# Requirement already satisfied: packaging>=20.9 in /Users/annashitikova/Library/Python/3.11/lib/python/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.14.0->voyageai) (26.3)
# Requirement already satisfied: pyyaml>=5.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.14.0->voyageai) (6.0.3)
# Requirement already satisfied: tqdm>=4.42.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.14.0->voyageai) (4.70.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters>=0.3.8->voyageai) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters>=0.3.8->voyageai) (0.0.19)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters>=0.3.8->voyageai) (0.11.1)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters>=0.3.8->voyageai) (0.17.0)
# Requirement already satisfied: anyio in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=0.16.4->tokenizers>=0.14.0->voyageai) (4.14.2)
# Requirement already satisfied: httpcore==1.* in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=0.16.4->tokenizers>=0.14.0->voyageai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=0.16.4->tokenizers>=0.14.0->voyageai) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters>=0.3.8->voyageai) (3.1.1)
# Requirement already satisfied: distro>=1.7.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters>=0.3.8->voyageai) (1.9.0)
# Requirement already satisfied: orjson>=3.9.14 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters>=0.3.8->voyageai) (3.12.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters>=0.3.8->voyageai) (1.0.0)
# Requirement already satisfied: sniffio>=1.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters>=0.3.8->voyageai) (1.3.1)
# Requirement already satisfied: websockets>=15.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters>=0.3.8->voyageai) (17.1)
# Requirement already satisfied: xxhash>=3.0.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters>=0.3.8->voyageai) (4.0.1)
# Requirement already satisfied: zstandard>=0.23.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters>=0.3.8->voyageai) (0.25.0)
#
# [notice] A new release of pip is available: 23.2.1 -> 26.2.1
# [notice] To update, run: python3 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# Client Setup
from dotenv import load_dotenv
import voyageai

load_dotenv()

client = voyageai.Client()

# %%
# Chunk by section
import re


def chunk_by_section(document_text):
    pattern = r"\n## "
    return re.split(pattern, document_text)

# %%
# Embedding Generation
def generate_embedding(text, model="voyage-3-large", input_type="query"):
    result = client.embed([text], model=model, input_type=input_type)

    return result.embeddings[0]

# %%
with open("./report.md", "r") as f:
    text = f.read()

chunks = chunk_by_section(text)

embedding = generate_embedding(chunks[0])
print(f"Embedding generated successfully! Length: {len(embedding)}")
# Out:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# Cell In[13], line 6
#       2     text = f.read()
#       3
#       4 chunks = chunk_by_section(text)
#       5
# ----> 6 embedding = generate_embedding(chunks[0])
#       7 print(f"Embedding generated successfully! Length: {len(embedding)}")
#
# Cell In[10], line 3, in generate_embedding(text, model, input_type)
#       2 def generate_embedding(text, model="voyage-3-large", input_type="query"):
# ----> 3     result = client.embed([text], model=model, input_type=input_type)
#       4
#       5     return result.embeddings[0]
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/voyageai/client.py:96, in Client.embed(self, texts, model, input_type, truncation, output_dtype, output_dimension)
#      86     return embed_local(
#      87         texts=texts,
#      88         model=model,
#    (...)     92         output_dimension=output_dimension,
#      93     )
#      95 # API models require an API key
# ---> 96 self._require_api_key()
#      98 response = None
#      99 for attempt in self._make_retry_controller():
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/voyageai/_base.py:95, in _BaseClient._require_api_key(self)
#      87 """Raise a clear error if no API key is configured.
#      88
#      89 The client allows a missing key so local models can run without one, but
#    (...)     92 the request layer with a less actionable error.
#      93 """
#      94 if not self.api_key:
# ---> 95     raise AuthenticationError(
#      96         "An API key is required for API-based models. "
#      97         "Set your API key via the VOYAGE_API_KEY environment variable or "
#      98         "pass it to the client (api_key=...)."
#      99     )
#
# AuthenticationError: An API key is required for API-based models. Set your API key via the VOYAGE_API_KEY environment variable or pass it to the client (api_key=...).
